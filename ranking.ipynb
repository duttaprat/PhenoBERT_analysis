# %%
from __future__ import division
import pandas as pd
import numpy as np
import operator
import pickle

# %%
df = pd.read_csv("PhenoBERT_score_synonym_0.csv")

# %%
df
# Out:
#                           Sentence  \
# 0   Any anomaly of cell structure.
# 1   Any anomaly of cell structure.
# 2   Any anomaly of cell structure.
# 3   Any anomaly of cell structure.
# 4   Any anomaly of cell structure.
# ..                             ...
# 70  Any anomaly of cell structure.
# 71  Any anomaly of cell structure.
# 72  Any anomaly of cell structure.
# 73  Any anomaly of cell structure.
# 74  Any anomaly of cell structure.
#
#                                      Description     Score      HPO_ID  \
# 0                                   Growth issue  0.687988  HP:0001507
# 1   Abnormality of prenatal development or birth  0.671875  HP:0001197
# 2                                         Cancer  0.626465  HP:0002664
# 3                    Abnormal cellular phenotype  0.611816  HP:0025354
# 4                  Genitourinary tract anomalies  0.608398  HP:0000119
# ..                                           ...       ...         ...
# 70                      Neurologic abnormalities  0.450195  HP:0000707
# 71                bone thoracic segment of trunk  0.430908  HP:0041054
# 72              Fractured pelvic region of trunk  0.423340  HP:0041161
# 73                                      Dysmelia  0.393799  HP:0040064
# 74           Fractured thoracic segment of trunk  0.378662  HP:0041054
#
#        Remarks
# 0      Synonym
# 1      Synonym
# 2      Synonym
# 3   Definition
# 4      Synonym
# ..         ...
# 70     Synonym
# 71     Synonym
# 72  Definition
# 73     Synonym
# 74  Definition
#
# [75 rows x 5 columns]

# %%
df[df['HPO_ID']=='HP:0025354'].index.values
# Out:
# array([3])

# %%
temp=0
list1=[]
for i, g in df.groupby(['HPO_ID']):
    #print (g)
    f=g[g.Score == g.Score.max()]
    print(f)
    list1.append(f)
    temp=temp+1
    print(temp)
print(i)
# Out:
#                           Sentence        Description     Score      HPO_ID  \
# 10  Any anomaly of cell structure.  Organ abnormality  0.591309  HP:0000118
#
#     Remarks
# 10  Synonym
# 1
#                          Sentence                    Description     Score  \
# 4  Any anomaly of cell structure.  Genitourinary tract anomalies  0.608398
#
#        HPO_ID  Remarks
# 4  HP:0000119  Synonym
# 2
#                           Sentence                  Description     Score  \
# 33  Any anomaly of cell structure.  Abnormality of head or neck  0.538086
#
#         HPO_ID  Remarks
# 33  HP:0000152  Synonym
# 3
#                           Sentence             Description    Score  \
# 50  Any anomaly of cell structure.  Abnormality of the eye  0.50293
#
#         HPO_ID     Remarks
# 50  HP:0000478  Definition
# 4
#                          Sentence  Description     Score      HPO_ID  Remarks
# 7  Any anomaly of cell structure.  Ear anomaly  0.601562  HP:0000598  Synonym
# 5
#                           Sentence                        Description  \
# 32  Any anomaly of cell structure.  Abnormality of the nervous system
#
#        Score      HPO_ID  Remarks
# 32  0.540039  HP:0000707  Synonym
# 6
#                           Sentence                Description     Score  \
# 31  Any anomaly of cell structure.  Abnormality of the breast  0.540527
#
#         HPO_ID     Remarks
# 31  HP:0000769  Definition
# 7
#                           Sentence                          Description  \
# 39  Any anomaly of cell structure.  Abnormality of the endocrine system
#
#       Score      HPO_ID     Remarks
# 39  0.52832  HP:0000818  Definition
# 8
#                           Sentence         Description     Score      HPO_ID  \
# 14  Any anomaly of cell structure.  Skeletal anomalies  0.587891  HP:0000924
#
#     Remarks
# 14  Synonym
# 9
#                          Sentence  \
# 1  Any anomaly of cell structure.
#
#                                     Description     Score      HPO_ID  Remarks
# 1  Abnormality of prenatal development or birth  0.671875  HP:0001197  Synonym
# 10
#                          Sentence   Description     Score      HPO_ID  Remarks
# 0  Any anomaly of cell structure.  Growth issue  0.687988  HP:0001507  Synonym
# 11
#                           Sentence                    Description     Score  \
# 21  Any anomaly of cell structure.  Abnormality of the integument  0.560059
#
#         HPO_ID     Remarks
# 21  HP:0001574  Definition
# 12
#                           Sentence               Description     Score  \
# 41  Any anomaly of cell structure.  Abnormality of the voice  0.518066
#
#         HPO_ID  Remarks
# 41  HP:0001608  Synonym
# 13
#                           Sentence                 Description    Score  \
# 26  Any anomaly of cell structure.  Cardiovascular abnormality  0.55127
#
#         HPO_ID  Remarks
# 26  HP:0001626  Synonym
# 14
#                          Sentence                              Description  \
# 6  Any anomaly of cell structure.  Abnormality of the hematopoietic system
#
#       Score      HPO_ID  Remarks
# 6  0.602539  HP:0001871  Synonym
# 15
#                           Sentence                            Description  \
# 22  Any anomaly of cell structure.  Abnormality of metabolism/homeostasis
#
#        Score      HPO_ID     Remarks
# 22  0.558594  HP:0001939  Definition
# 16
#                           Sentence              Description     Score  \
# 37  Any anomaly of cell structure.  Respiratory abnormality  0.533691
#
#         HPO_ID  Remarks
# 37  HP:0002086  Synonym
# 17
#                          Sentence Description     Score      HPO_ID  Remarks
# 2  Any anomaly of cell structure.      Cancer  0.626465  HP:0002664  Synonym
# 18
#                           Sentence                       Description  \
# 28  Any anomaly of cell structure.  Abnormality of the immune system
#
#        Score      HPO_ID     Remarks
# 28  0.546875  HP:0002715  Definition
# 19
#                           Sentence                     Description     Score  \
# 38  Any anomaly of cell structure.  Abnormality of the musculature  0.532715
#
#         HPO_ID     Remarks
# 38  HP:0003011  Definition
# 20
#                           Sentence                       Description    Score  \
# 11  Any anomaly of cell structure.  Abnormality of connective tissue  0.59082
#
#         HPO_ID     Remarks
# 11  HP:0003549  Definition
# 21
#                           Sentence                          Description  \
# 48  Any anomaly of cell structure.  Abnormality of the digestive system
#
#        Score      HPO_ID     Remarks
# 48  0.507324  HP:0025031  Definition
# 22
#                           Sentence             Description     Score  \
# 56  Any anomaly of cell structure.  Constitutional symptom  0.493652
#
#         HPO_ID     Remarks
# 56  HP:0025142  Definition
# 23
#                          Sentence                  Description     Score  \
# 3  Any anomaly of cell structure.  Abnormal cellular phenotype  0.611816
#
#        HPO_ID     Remarks
# 3  HP:0025354  Definition
# 24
#                          Sentence   Description     Score      HPO_ID  Remarks
# 5  Any anomaly of cell structure.  Limb anomaly  0.607422  HP:0040064  Synonym
# 25
#                           Sentence                     Description     Score  \
# 71  Any anomaly of cell structure.  bone thoracic segment of trunk  0.430908
#
#         HPO_ID  Remarks
# 71  HP:0041054  Synonym
# 26
#                           Sentence      Description     Score      HPO_ID  \
# 65  Any anomaly of cell structure.  Fractured trunk  0.459473  HP:0041158
#
#        Remarks
# 65  Definition
# 27
#                           Sentence                  Description     Score  \
# 69  Any anomaly of cell structure.  bone pelvic region of trunk  0.456543
#
#         HPO_ID  Remarks
# 69  HP:0041161  Synonym
# 28
#                           Sentence                         Description  \
# 63  Any anomaly of cell structure.  Abnormality of the thoracic cavity
#
#        Score      HPO_ID     Remarks
# 63  0.478027  HP:0045027  Definition
# 29
# HP:0045027

# %%
df1 = pd.DataFrame()
#df1.iloc[0] = f
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_found = pd.concat(list1)
df_found
# Out:
#                           Sentence  \
# 10  Any anomaly of cell structure.
# 4   Any anomaly of cell structure.
# 33  Any anomaly of cell structure.
# 50  Any anomaly of cell structure.
# 7   Any anomaly of cell structure.
# 32  Any anomaly of cell structure.
# 31  Any anomaly of cell structure.
# 39  Any anomaly of cell structure.
# 14  Any anomaly of cell structure.
# 1   Any anomaly of cell structure.
# 0   Any anomaly of cell structure.
# 21  Any anomaly of cell structure.
# 41  Any anomaly of cell structure.
# 26  Any anomaly of cell structure.
# 6   Any anomaly of cell structure.
# 22  Any anomaly of cell structure.
# 37  Any anomaly of cell structure.
# 2   Any anomaly of cell structure.
# 28  Any anomaly of cell structure.
# 38  Any anomaly of cell structure.
# 11  Any anomaly of cell structure.
# 48  Any anomaly of cell structure.
# 56  Any anomaly of cell structure.
# 3   Any anomaly of cell structure.
# 5   Any anomaly of cell structure.
# 71  Any anomaly of cell structure.
# 65  Any anomaly of cell structure.
# 69  Any anomaly of cell structure.
# 63  Any anomaly of cell structure.
#
#                                      Description     Score      HPO_ID  \
# 10                             Organ abnormality  0.591309  HP:0000118
# 4                  Genitourinary tract anomalies  0.608398  HP:0000119
# 33                   Abnormality of head or neck  0.538086  HP:0000152
# 50                        Abnormality of the eye  0.502930  HP:0000478
# 7                                    Ear anomaly  0.601562  HP:0000598
# 32             Abnormality of the nervous system  0.540039  HP:0000707
# 31                     Abnormality of the breast  0.540527  HP:0000769
# 39           Abnormality of the endocrine system  0.528320  HP:0000818
# 14                            Skeletal anomalies  0.587891  HP:0000924
# 1   Abnormality of prenatal development or birth  0.671875  HP:0001197
# 0                                   Growth issue  0.687988  HP:0001507
# 21                 Abnormality of the integument  0.560059  HP:0001574
# 41                      Abnormality of the voice  0.518066  HP:0001608
# 26                    Cardiovascular abnormality  0.551270  HP:0001626
# 6        Abnormality of the hematopoietic system  0.602539  HP:0001871
# 22         Abnormality of metabolism/homeostasis  0.558594  HP:0001939
# 37                       Respiratory abnormality  0.533691  HP:0002086
# 2                                         Cancer  0.626465  HP:0002664
# 28              Abnormality of the immune system  0.546875  HP:0002715
# 38                Abnormality of the musculature  0.532715  HP:0003011
# 11              Abnormality of connective tissue  0.590820  HP:0003549
# 48           Abnormality of the digestive system  0.507324  HP:0025031
# 56                        Constitutional symptom  0.493652  HP:0025142
# 3                    Abnormal cellular phenotype  0.611816  HP:0025354
# 5                                   Limb anomaly  0.607422  HP:0040064
# 71                bone thoracic segment of trunk  0.430908  HP:0041054
# 65                               Fractured trunk  0.459473  HP:0041158
# 69                   bone pelvic region of trunk  0.456543  HP:0041161
# 63            Abnormality of the thoracic cavity  0.478027  HP:0045027
#
#        Remarks
# 10     Synonym
# 4      Synonym
# 33     Synonym
# 50  Definition
# 7      Synonym
# 32     Synonym
# 31  Definition
# 39  Definition
# 14     Synonym
# 1      Synonym
# 0      Synonym
# 21  Definition
# 41     Synonym
# 26     Synonym
# 6      Synonym
# 22  Definition
# 37     Synonym
# 2      Synonym
# 28  Definition
# 38  Definition
# 11  Definition
# 48  Definition
# 56  Definition
# 3   Definition
# 5      Synonym
# 71     Synonym
# 65  Definition
# 69     Synonym
# 63  Definition

# %%
df_new_sorted = df_found.sort_values(by='Score', ascending=False)
df_new_sorted.reset_index()
# Out:
#     index                        Sentence  \
# 0       0  Any anomaly of cell structure.
# 1       1  Any anomaly of cell structure.
# 2       2  Any anomaly of cell structure.
# 3       3  Any anomaly of cell structure.
# 4       4  Any anomaly of cell structure.
# 5       5  Any anomaly of cell structure.
# 6       6  Any anomaly of cell structure.
# 7       7  Any anomaly of cell structure.
# 8      10  Any anomaly of cell structure.
# 9      11  Any anomaly of cell structure.
# 10     14  Any anomaly of cell structure.
# 11     21  Any anomaly of cell structure.
# 12     22  Any anomaly of cell structure.
# 13     26  Any anomaly of cell structure.
# 14     28  Any anomaly of cell structure.
# 15     31  Any anomaly of cell structure.
# 16     32  Any anomaly of cell structure.
# 17     33  Any anomaly of cell structure.
# 18     37  Any anomaly of cell structure.
# 19     38  Any anomaly of cell structure.
# 20     39  Any anomaly of cell structure.
# 21     41  Any anomaly of cell structure.
# 22     48  Any anomaly of cell structure.
# 23     50  Any anomaly of cell structure.
# 24     56  Any anomaly of cell structure.
# 25     63  Any anomaly of cell structure.
# 26     65  Any anomaly of cell structure.
# 27     69  Any anomaly of cell structure.
# 28     71  Any anomaly of cell structure.
#
#                                      Description     Score      HPO_ID  \
# 0                                   Growth issue  0.687988  HP:0001507
# 1   Abnormality of prenatal development or birth  0.671875  HP:0001197
# 2                                         Cancer  0.626465  HP:0002664
# 3                    Abnormal cellular phenotype  0.611816  HP:0025354
# 4                  Genitourinary tract anomalies  0.608398  HP:0000119
# 5                                   Limb anomaly  0.607422  HP:0040064
# 6        Abnormality of the hematopoietic system  0.602539  HP:0001871
# 7                                    Ear anomaly  0.601562  HP:0000598
# 8                              Organ abnormality  0.591309  HP:0000118
# 9               Abnormality of connective tissue  0.590820  HP:0003549
# 10                            Skeletal anomalies  0.587891  HP:0000924
# 11                 Abnormality of the integument  0.560059  HP:0001574
# 12         Abnormality of metabolism/homeostasis  0.558594  HP:0001939
# 13                    Cardiovascular abnormality  0.551270  HP:0001626
# 14              Abnormality of the immune system  0.546875  HP:0002715
# 15                     Abnormality of the breast  0.540527  HP:0000769
# 16             Abnormality of the nervous system  0.540039  HP:0000707
# 17                   Abnormality of head or neck  0.538086  HP:0000152
# 18                       Respiratory abnormality  0.533691  HP:0002086
# 19                Abnormality of the musculature  0.532715  HP:0003011
# 20           Abnormality of the endocrine system  0.528320  HP:0000818
# 21                      Abnormality of the voice  0.518066  HP:0001608
# 22           Abnormality of the digestive system  0.507324  HP:0025031
# 23                        Abnormality of the eye  0.502930  HP:0000478
# 24                        Constitutional symptom  0.493652  HP:0025142
# 25            Abnormality of the thoracic cavity  0.478027  HP:0045027
# 26                               Fractured trunk  0.459473  HP:0041158
# 27                   bone pelvic region of trunk  0.456543  HP:0041161
# 28                bone thoracic segment of trunk  0.430908  HP:0041054
#
#        Remarks
# 0      Synonym
# 1      Synonym
# 2      Synonym
# 3   Definition
# 4      Synonym
# 5      Synonym
# 6      Synonym
# 7      Synonym
# 8      Synonym
# 9   Definition
# 10     Synonym
# 11  Definition
# 12  Definition
# 13     Synonym
# 14  Definition
# 15  Definition
# 16     Synonym
# 17     Synonym
# 18     Synonym
# 19  Definition
# 20  Definition
# 21     Synonym
# 22  Definition
# 23  Definition
# 24  Definition
# 25  Definition
# 26  Definition
# 27     Synonym
# 28     Synonym

# %%
def group_ranking(df):
    list1=[]
    for i, g in df.groupby(['HPO_ID']):
        f=g[g.Score == g.Score.max()]
        list1.append(f)
    df_found = pd.concat(list1)
    df_sorted = df_found.sort_values(by='Score', ascending=False)
    df_new = df_sorted.reset_index()
    print(df_new)

# %%
group_ranking(df)
# Out:
#     index                        Sentence  \
# 0       0  Any anomaly of cell structure.
# 1       1  Any anomaly of cell structure.
# 2       2  Any anomaly of cell structure.
# 3       3  Any anomaly of cell structure.
# 4       4  Any anomaly of cell structure.
# 5       5  Any anomaly of cell structure.
# 6       6  Any anomaly of cell structure.
# 7       7  Any anomaly of cell structure.
# 8      10  Any anomaly of cell structure.
# 9      11  Any anomaly of cell structure.
# 10     14  Any anomaly of cell structure.
# 11     21  Any anomaly of cell structure.
# 12     22  Any anomaly of cell structure.
# 13     26  Any anomaly of cell structure.
# 14     28  Any anomaly of cell structure.
# 15     31  Any anomaly of cell structure.
# 16     32  Any anomaly of cell structure.
# 17     33  Any anomaly of cell structure.
# 18     37  Any anomaly of cell structure.
# 19     38  Any anomaly of cell structure.
# 20     39  Any anomaly of cell structure.
# 21     41  Any anomaly of cell structure.
# 22     48  Any anomaly of cell structure.
# 23     50  Any anomaly of cell structure.
# 24     56  Any anomaly of cell structure.
# 25     63  Any anomaly of cell structure.
# 26     65  Any anomaly of cell structure.
# 27     69  Any anomaly of cell structure.
# 28     71  Any anomaly of cell structure.
#
#                                      Description     Score      HPO_ID  \
# 0                                   Growth issue  0.687988  HP:0001507
# 1   Abnormality of prenatal development or birth  0.671875  HP:0001197
# 2                                         Cancer  0.626465  HP:0002664
# 3                    Abnormal cellular phenotype  0.611816  HP:0025354
# 4                  Genitourinary tract anomalies  0.608398  HP:0000119
# 5                                   Limb anomaly  0.607422  HP:0040064
# 6        Abnormality of the hematopoietic system  0.602539  HP:0001871
# 7                                    Ear anomaly  0.601562  HP:0000598
# 8                              Organ abnormality  0.591309  HP:0000118
# 9               Abnormality of connective tissue  0.590820  HP:0003549
# 10                            Skeletal anomalies  0.587891  HP:0000924
# 11                 Abnormality of the integument  0.560059  HP:0001574
# 12         Abnormality of metabolism/homeostasis  0.558594  HP:0001939
# 13                    Cardiovascular abnormality  0.551270  HP:0001626
# 14              Abnormality of the immune system  0.546875  HP:0002715
# 15                     Abnormality of the breast  0.540527  HP:0000769
# 16             Abnormality of the nervous system  0.540039  HP:0000707
# 17                   Abnormality of head or neck  0.538086  HP:0000152
# 18                       Respiratory abnormality  0.533691  HP:0002086
# 19                Abnormality of the musculature  0.532715  HP:0003011
# 20           Abnormality of the endocrine system  0.528320  HP:0000818
# 21                      Abnormality of the voice  0.518066  HP:0001608
# 22           Abnormality of the digestive system  0.507324  HP:0025031
# 23                        Abnormality of the eye  0.502930  HP:0000478
# 24                        Constitutional symptom  0.493652  HP:0025142
# 25            Abnormality of the thoracic cavity  0.478027  HP:0045027
# 26                               Fractured trunk  0.459473  HP:0041158
# 27                   bone pelvic region of trunk  0.456543  HP:0041161
# 28                bone thoracic segment of trunk  0.430908  HP:0041054
#
#        Remarks
# 0      Synonym
# 1      Synonym
# 2      Synonym
# 3   Definition
# 4      Synonym
# 5      Synonym
# 6      Synonym
# 7      Synonym
# 8      Synonym
# 9   Definition
# 10     Synonym
# 11  Definition
# 12  Definition
# 13     Synonym
# 14  Definition
# 15  Definition
# 16     Synonym
# 17     Synonym
# 18     Synonym
# 19  Definition
# 20  Definition
# 21     Synonym
# 22  Definition
# 23  Definition
# 24  Definition
# 25  Definition
# 26  Definition
# 27     Synonym
# 28     Synonym
